# %%
"""
PyRamen Homework Starter.

"""

import pandas as pd
from pathlib import Path

# %%
# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('../python-homework_Palmy/menu_data.csv')
menu_dataframe = pd.read_csv(menu_filepath)
menu_dataframe
# Out:
#                                               item    category  \
# 0                                          edamame  appetizers
# 1                                      house salad  appetizers
# 2                          cucumber sunomono salad  appetizers
# 3                     hiyashi wakame seaweed salad  appetizers
# 4                                    agedashi tofu  appetizers
# 5                                   hiyayakko tofu  appetizers
# 6                                   pork floss bao  appetizers
# 7                                       kakuni bao  appetizers
# 8                      edamame fried gyoza (vegan)  appetizers
# 9                                      fried gyoza  appetizers
# 10                                        takoyaki  appetizers
# 11                             rock shrimp tempura  appetizers
# 12                         soft-shell crab tempura  appetizers
# 13                            ebi katsu shrimp bao  appetizers
# ...

# %%
sales_filepath = Path('../python-homework_Palmy/sales_data.csv')
sales_dataframe = pd.read_csv(sales_filepath)
sales_dataframe
# Out:
#        Line_Item_ID        Date  Credit_Card_Number  Quantity  \
# 0                 1  01-01-2017    7437926611570799         1
# 1                 2  01-01-2017    7437926611570799         1
# 2                 3  01-01-2017    8421920068932819         3
# 3                 4  01-01-2017    8421920068932819         3
# 4                 5  01-01-2017    4787310681569648         1
# ...             ...         ...                 ...       ...
# 74119         74120  12-31-2018    1697055332228941         4
# 74120         74121  12-31-2018    6800009643487106         1
# 74121         74122  12-31-2018    6800009643487106         1
# 74122         74123  12-31-2018    5981057609583653         2
# 74123         74124  12-31-2018    5981057609583653         2
#
#                    Menu_Item
# 0           spicy miso ramen
# 1           spicy miso ramen
# 2          tori paitan ramen
# 3          tori paitan ramen
# 4       truffle butter ramen
# ...                      ...
# ...

# %%
with open(menu_filepath,'r') as file:
    # text=file.read()
    for line in file:
        print(f"line: {line}")
# Out:
# line: item,category,description,price,cost
#
# line: edamame,appetizers,"boiled soybeans, maldon sea salt",4,1
#
# line: house salad,appetizers,"mixed greens, cherry tomatoes, cucumber, house ginger dressing",4,2
#
# line: cucumber sunomono salad,appetizers,"cucumber, ponzu dressing, pickled ginger sproud, sesame seeds",5,2
#
# line: hiyashi wakame seaweed salad,appetizers,"sweet soy-marinated wakame seaweed threads, pickled ginger sprout, sesame seeds",5,2
#
# line: agedashi tofu,appetizers,"tempura battered tofu, katsuobushi, tsuyu broth, scallions",5,2
#
# line: hiyayakko tofu,appetizers,"chilled soft tofu, house shoyu, katsuobushi, ginger, scallions",5,2
#
# line: pork floss bao,appetizers,"two steamed buns, minced lean slow braised niman, ranch pork belly, cucumbers, sriracha mayo",4,2
#
# line: kakuni bao,appetizers,"two steamed buns, chopped fatty slow braised niman ranch pork belly, cucumbers, house bao sauce",6,3
#
# ...

# %%
# @TODO: Initialize list objects to hold our menu and sales data
def make_list(file_path):
    csv_list = []
    with open(file_path, 'r') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        next(csv_reader)
        for row in csv_reader:
            csv_list.append(row)
    return csv_list

# %%
# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
def make_report(menu_list, sales_list):
    report = {}

# %%
# @TODO: Read in the menu data into the menu list
menu_list = []
sales_list = []

# %%
# Initialize a row counter variable
row_count = 0
row_revenue = 0
row_cogs = 0
row_profit = 0

# %%
# @TODO: Loop over every row in the sales list object
def make_report(menu_list, sales_list):
    report = {}
    for row in sales_list:
        Quantity = row[3]
        Sales_item = row[4]
        if Sales_item not in report:
            report[Sales_item] = {"01-count": 0,"02-revenue": 0,"03-cogs": 0,"04-profit": 0}
            
        for Menu_Item in menu_list:
            Menu_Item_Name = Menu_Item[0]
            Menu_Item_Price = Menu_Item[3]
            Menu_Item_Cost = Menu_Item[4]
            
            profit = float(Menu_Item_Price) - float(Menu_Item_Cost)

            if Sales_item == Menu_Item_Name:
                report_sales_item = report[sales_item]
                report[sales_item]["01-count"] += int(Quantity)
                report[sales_item]["02-revenue"] += float(Menu_Item_Price) * int(Quantity)
                report[sales_item]["03-cogs"] += float(Menu_Item_Cost) * int(Quantity)
                report[sales_item]["04-profit"] += profit * int(Quantity)
    return report

# %%
def write_table_report(report, report_path, mode):
    with open(report_path, 'w') as report_file:
        report_file.write("PyRamen Report\n")
        report_file.write("\n|Item|01-count|02-revenue|03-cogs|04-profit|\n")
        for item in report:
            reportfile = report[item]
            report_file.write(f"(|{item.Item()}|{reportfile['count']}|{reportfile["revenue"]}|{reportfile["cogs"]}|{reportfile["profit"]}|\n)")
# Out:
#   Cell In[68], line 7
#     report_file.write(f"(|{item.Item()}|{reportfile['count']}|{reportfile["revenue"]}|{reportfile["cogs"]}|{reportfile["profit"]}|\n)")
#                                                                            ^
# SyntaxError: f-string: unmatched '['

# %%
P
